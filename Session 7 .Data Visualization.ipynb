# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline # this ensure all the charts will visiual in the jupyter
# Out:
# UsageError: unrecognized arguments: # this ensure all the charts will visiual in the jupyter

# %%
Iris=pd.read_csv('C:/Users/Vikrant/Desktop/Documents\Python Scripts/Iris.csv')

# %%
cars=pd.read_csv('C:/Users/Vikrant/Desktop/Documents/Python Scripts/mtcars.csv')

# %%
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
cars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
cars.cyl.unique()
# Out:
# array([6, 4, 8], dtype=int64)

# %%
cars.cyl.value_counts()
# Out:
# cyl
# 8    14
# 4    11
# 6     7
# Name: count, dtype: int64

# %%
plot=sns.countplot(data=cars,x='cyl')
plot.set_title('Count of Cars by Number of Cylinders')
plot.set_xlabel('Number of Cylinders')
plot.set_ylabel('Count')
plt.show()

# %%
plt.pie(cars.hp)
plt.show()

# %%
sns.scatterplot(data=Iris,x='SepalLengthCm',y='SepalWidthCm')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
cars.gear.unique()
# Out:
# array([4, 3, 5], dtype=int64)

# %%
cars.gear.value_counts()
# Out:
# gear
# 3    15
# 4    12
# 5     5
# Name: count, dtype: int64

# %%
sns.countplot(data=cars,x='gear')
# Out:
# <Axes: xlabel='gear', ylabel='count'>

# %%
sns.distplot(cars.mpg)
# Out:
# C:\Users\Vikrant\AppData\Local\Temp\ipykernel_13780\1934615651.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.mpg)
# C:\Users\Vikrant\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='mpg', ylabel='Density'>

# %%
sns.histplot(cars.mpg, bins=5)
# Out:
# C:\Users\Vikrant\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
sns.scatterplot(data=Iris,x='SepalLengthCm',y='SepalWidthCm')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data= {'Category':['A','B','C','D','E','F'],
      'Values': [25,66,45,78,96,99]}

# %%
df=pd.DataFrame(data)

# %%
categories=['A','B','C','D','E']
values =[25,66,85,75,96]
plt.bar(categories,values,color='skyblue')
plt.xlabel('categories')
plt.ylabel('values')
plt.title('Categories Wise')

for i in range(len(categories)):
    plt.text(categories[i], values[i],str(values[i]),ha='center',va='bottom')

plt.show()

# %%
plt.hist(cars.mpg, bins=10)
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)
